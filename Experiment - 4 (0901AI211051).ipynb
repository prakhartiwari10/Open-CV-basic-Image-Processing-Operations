# %%
import numpy as np
import cv2
import random
import matplotlib.pyplot as plt
x = np.linspace(-10, 10, 100)
y = np.sin(x)/x
plt.subplot(2, 3, 1)
plt.title('f(x)=Sin(x)/x')
plt.xlabel('x ----->')
plt.ylabel('y ----->')
plt.plot(x,y,'-.')
y = 2**x+3
plt.subplot(2, 3, 2)
plt.title('f(x)=2^x+3')
plt.xlabel('x ----->')
plt.ylabel('y ----->')
plt.plot(x,y)
y = np.log(x)
plt.subplot(2, 3, 3)
plt.title('f(x)=log(x)')
plt.xlabel('x ----->')
plt.ylabel('y ----->')
plt.plot(x,y)
y = np.tan(x)
plt.subplot(2, 3, 4)
plt.title('f(x)=tan(x)')
plt.xlabel('x ----->')
plt.ylabel('y ----->')
plt.plot(x,y)
y = x**2+x+1
plt.subplot(2, 3, 5)
plt.title('f(x)=x^2+x+1')
plt.xlabel('x ----->')
plt.ylabel('y ----->')
plt.plot(x,y)
y = (x**3+x+1)/(x**2)
plt.subplot(2, 3, 6)
plt.title('f(x)=(x^3+x+1)/(x^2)')
plt.xlabel('x ----->')
plt.ylabel('y ----->')
plt.plot(x,y)
plt.show()
# Out:
# /tmp/ipykernel_7518/1577375410.py:18: RuntimeWarning: invalid value encountered in log
#   y = np.log(x)
