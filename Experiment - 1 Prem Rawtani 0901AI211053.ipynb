# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
img = cv2.imread("/home/prakhar/Downloads/Fruits.png")

# %%
print(img)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
print(img.shape)
# Out:
# (1131, 1698, 3)

# %%
cv2.imshow('Image', img)

# Wait fobr a key press and close the window
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x56483a0ed580) is not the object's thread (0x56483a9ae7a0).
# Cannot move to target thread (0x56483a0ed580)
#
# QObject::moveToThread: Current thread (0x56483a0ed580) is not the object's thread (0x56483a9ae7a0).
# Cannot move to target thread (0x56483a0ed580)
#
# QObject::moveToThread: Current thread (0x56483a0ed580) is not the object's thread (0x56483a9ae7a0).
# Cannot move to target thread (0x56483a0ed580)
#
# QObject::moveToThread: Current thread (0x56483a0ed580) is not the object's thread (0x56483a9ae7a0).
# Cannot move to target thread (0x56483a0ed580)
#
# QObject::moveToThread: Current thread (0x56483a0ed580) is not the object's thread (0x56483a9ae7a0).
# Cannot move to target thread (0x56483a0ed580)
#
# QObject::moveToThread: Current thread (0x56483a0ed580) is not the object's thread (0x56483a9ae7a0).
# Cannot move to target thread (0x56483a0ed580)
#
# ...

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2.imshow('Image', gray_image)

# Wait for a key press and close the window
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x56483a0ed580) is not the object's thread (0x56483a9ae7a0).
# Cannot move to target thread (0x56483a0ed580)
#
# QObject::moveToThread: Current thread (0x56483a0ed580) is not the object's thread (0x56483a9ae7a0).
# Cannot move to target thread (0x56483a0ed580)
#
# QObject::moveToThread: Current thread (0x56483a0ed580) is not the object's thread (0x56483a9ae7a0).
# Cannot move to target thread (0x56483a0ed580)
#
# QObject::moveToThread: Current thread (0x56483a0ed580) is not the object's thread (0x56483a9ae7a0).
# Cannot move to target thread (0x56483a0ed580)
#
# QObject::moveToThread: Current thread (0x56483a0ed580) is not the object's thread (0x56483a9ae7a0).
# Cannot move to target thread (0x56483a0ed580)
#
# QObject::moveToThread: Current thread (0x56483a0ed580) is not the object's thread (0x56483a9ae7a0).
# Cannot move to target thread (0x56483a0ed580)
#
# ...

# %%
img[:,:,2 ]=0

# %%
cv2.imshow('Image', img)

# Wait for a key press and close the window
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x56483a0ed580) is not the object's thread (0x56483a9ae7a0).
# Cannot move to target thread (0x56483a0ed580)
#
# QObject::moveToThread: Current thread (0x56483a0ed580) is not the object's thread (0x56483a9ae7a0).
# Cannot move to target thread (0x56483a0ed580)
#
# QObject::moveToThread: Current thread (0x56483a0ed580) is not the object's thread (0x56483a9ae7a0).
# Cannot move to target thread (0x56483a0ed580)
#
# QObject::moveToThread: Current thread (0x56483a0ed580) is not the object's thread (0x56483a9ae7a0).
# Cannot move to target thread (0x56483a0ed580)
#
# QObject::moveToThread: Current thread (0x56483a0ed580) is not the object's thread (0x56483a9ae7a0).
# Cannot move to target thread (0x56483a0ed580)
#
# QObject::moveToThread: Current thread (0x56483a0ed580) is not the object's thread (0x56483a9ae7a0).
# Cannot move to target thread (0x56483a0ed580)
#
# ...

# %%
print("Image width is: ", img.shape[1])
print("Image height is: ", img.shape[0])
# Out:
# Image width is:  1698
# Image height is:  1131

# %%
resized_image = cv2.resize(img, (200, 200))

# %%
print("Image width is: ", resized_image.shape[1])
print("Image height is: ", resized_image.shape[0])
# Out:
# Image width is:  200
# Image height is:  200

# %%
cv2.imshow('Image', resized_image)

# Wait for a key press and close the window
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x56483a0ed580) is not the object's thread (0x56483a9ae7a0).
# Cannot move to target thread (0x56483a0ed580)
#
# QObject::moveToThread: Current thread (0x56483a0ed580) is not the object's thread (0x56483a9ae7a0).
# Cannot move to target thread (0x56483a0ed580)
#
# QObject::moveToThread: Current thread (0x56483a0ed580) is not the object's thread (0x56483a9ae7a0).
# Cannot move to target thread (0x56483a0ed580)
#
# QObject::moveToThread: Current thread (0x56483a0ed580) is not the object's thread (0x56483a9ae7a0).
# Cannot move to target thread (0x56483a0ed580)
#
# QObject::moveToThread: Current thread (0x56483a0ed580) is not the object's thread (0x56483a9ae7a0).
# Cannot move to target thread (0x56483a0ed580)
#
# QObject::moveToThread: Current thread (0x56483a0ed580) is not the object's thread (0x56483a9ae7a0).
# Cannot move to target thread (0x56483a0ed580)
#
# ...

# %%
# flipping vertically
img_vertical_flip = cv2.flip(img, 0)
img_horizontal_flip = cv2.flip(img, 1)
img_both_flip = cv2.flip(img, -1)

# %%
cv2.imshow('Image', img_both_flip)

# Wait for a key press and close the window
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x55b9e9ce97a0) is not the object's thread (0x55b9e9dfe7e0).
# Cannot move to target thread (0x55b9e9ce97a0)
#
# QObject::moveToThread: Current thread (0x55b9e9ce97a0) is not the object's thread (0x55b9e9dfe7e0).
# Cannot move to target thread (0x55b9e9ce97a0)
#
# QObject::moveToThread: Current thread (0x55b9e9ce97a0) is not the object's thread (0x55b9e9dfe7e0).
# Cannot move to target thread (0x55b9e9ce97a0)
#
# QObject::moveToThread: Current thread (0x55b9e9ce97a0) is not the object's thread (0x55b9e9dfe7e0).
# Cannot move to target thread (0x55b9e9ce97a0)
#
# QObject::moveToThread: Current thread (0x55b9e9ce97a0) is not the object's thread (0x55b9e9dfe7e0).
# Cannot move to target thread (0x55b9e9ce97a0)
#
# QObject::moveToThread: Current thread (0x55b9e9ce97a0) is not the object's thread (0x55b9e9dfe7e0).
# Cannot move to target thread (0x55b9e9ce97a0)
#
# ...

# %%
plt.imshow(img)
